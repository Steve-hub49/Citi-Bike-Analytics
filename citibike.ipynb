# %%
import pandas as pd

# %%
june2020 = pd.read_csv('resources/JC-202006-citibike/JC-202006-citibike-tripdata.csv')
july2020 = pd.read_csv('resources/JC-202007-citibike/JC-202007-citibike-tripdata.csv')
august2020 = pd.read_csv('resources/JC-202008-citibike/JC-202008-citibike-tripdata.csv')

# %%
Q32020 = pd.concat([june2020, july2020, august2020], join='inner')

# %%
Q32020
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               122  2020-06-01 00:02:21.7500  2020-06-01 00:04:24.3250
# 1              1282  2020-06-01 00:12:27.1090  2020-06-01 00:33:50.0540
# 2               186  2020-06-01 01:19:59.2090  2020-06-01 01:23:05.8930
# 3               131  2020-06-01 01:26:42.2050  2020-06-01 01:28:53.8040
# 4               266  2020-06-01 01:27:33.7090  2020-06-01 01:32:00.1890
# ...             ...                       ...                       ...
# 43262           162  2020-08-31 23:43:15.8540  2020-08-31 23:45:58.4550
# 43263           400  2020-08-31 23:46:19.9130  2020-08-31 23:53:00.3610
# 43264           288  2020-08-31 23:47:16.8680  2020-08-31 23:52:05.5550
# 43265           199  2020-08-31 23:50:37.2650  2020-08-31 23:53:56.9490
# 43266           333  2020-08-31 23:55:30.8050  2020-09-01 00:01:04.4110
#
#        start station id          start station name  start station latitude  \
# ...

# %%
Q32020.to_csv('Q32020.csv')
